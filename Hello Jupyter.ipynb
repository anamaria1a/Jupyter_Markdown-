# %% [markdown]
# # Homework S02 T01

# %% [markdown]
# ## Simple Calculations

# %% [markdown]
# - ### Creating Variables and Mathematical Operations

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
person1 = "Carla"
person2 = "Didac"
person3 = "Sira"
groupOfFriends = [person1, person2, person3]
print (groupOfFriends)
# Out:
# ['Carla', 'Didac', 'Sira']

# %%
x = 1979
y = 2021
z = x+y*y
print (z)
# Out:
# 4086420

# %%
child= input("how old are you?: ")
mom = input ("how old is your mother?: ")
superBeingAge = child+mom
print (superBeingAge)
# Out:
# how old are you?: 34
# how old is your mother?: 78
# 3478

# %% [markdown]
# - ### Casting

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %%
child= input("how old are you?: ")
mom = input ("how old is your mother?: ")
notSuperBeingAge = int(child)+int(mom)
print (notSuperBeingAge)
# Out:
# how old are you?: 34
# how old is your mother?: 78
# 112

# %%
notSuperBeingAge/int(superBeingAge)
# Out:
# 0.03220241518113859

# %%
float(notSuperBeingAge)* float(superBeingAge)
# Out:
# 389536.0

# %% [markdown]
# - ### String Techiques or *técnicas de* String

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %%
word = "string"
for x in word:
    print (x)
# Out:
# s
# t
# r
# i
# n
# g

# %%
print("string"[::-1])
print ("String"[2:6])
# Out:
# gnirts
# ring

# %%
if "s" in "string":
    print("hurray!")
# Out:
# hurray!

# %%
print(word.upper())
print (word.lower())
print(word.lower()+" " + word.upper()+ " " + word)
# Out:
# STRING
# string
# string STRING string

# %%
sayItWrite = "You have to find the write {} of letters for your text"
print(sayItWrite.format(word))
# Out:
# You have to find the write string of letters for your text

# %% [markdown]
# - ### Booleans

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %% [markdown]
# **Types of Booleans**
# <ol>
# <li>Boolean: True</li>
# <li>Boolean: False</li>
# </ol>

# %%
def verdadero() :
  return True

print(verdadero())
# Out:
# True

# %%
def mentira() :
  return False

if mentira():
  print("this is a lie")
else:
  print("it is false but truthful")
# Out:
# it is false but truthful

# %%
print(45<780)
# Out:
# True
